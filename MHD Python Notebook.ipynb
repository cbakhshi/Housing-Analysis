# %%
import pandas as pd
import numpy as np

housing_file = "housing_data_md.csv"

housing_data = pd.read_csv(housing_file)
housing_data
# Out:
#     Avg Sale To List Avg Sale To List Mom Avg Sale To List Yoy  Homes Sold  \
# 0           0.977355               -0.20%                0.30%      224604
# 1           0.979352                0.00%                0.40%        1193
# 2           0.989434               -0.10%               -0.10%        1258
# 3           0.994554               -0.20%               -0.20%         712
# 4           0.974388                0.00%                0.50%        2321
# 5                NaN                  NaN                  NaN        1072
# 6                NaN                  NaN                  NaN        1265
# 7           0.972731                0.10%                0.30%      165717
# 8           0.976482               -0.20%                0.20%         992
# 9           0.994434                1.00%               -0.10%         934
# 10          0.999509                1.50%                0.80%         513
# ...
