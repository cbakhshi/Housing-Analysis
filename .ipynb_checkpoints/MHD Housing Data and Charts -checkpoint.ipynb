# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

housing_file = "HousingDataClean.csv"

housing_data = pd.read_csv(housing_file)
housing_data
# Out:
#               City  Homes Sold  Inventory  Median Dom  Median List Price  \
# 0         National      159514     744443          66           266500.0
# 1         National      165717     765626          68           276700.0
# 2         National      222043     795934          60           286200.0
# 3         National      234992     826487          50           289100.0
# 4         National      263957     841678          44           287400.0
# 5         National      299010     854863          42           284400.0
# 6         National      263730     863238          42           278100.0
# 7         National      282330     844062          44           271800.0
# 8         National      250025     836653          46           283900.0
# 9         National      228331     806581          49           274600.0
# 10        National      216798     751114          50           267100.0
# 11        National      224604     667806          54           255100.0
# ...

# %%
housing_data.columns
# Out:
# Index(['City', 'Homes Sold', 'Inventory', 'Median Dom', 'Median List Price',
#        'Median Sale Price', 'New Listings', 'Period Begin', 'Period Duration',
#        'Period End', 'Price Drops', 'Property Type', 'Region'],
#       dtype='object')

# %%
#Create scatter plot for days on the market vs. median sale price per city per month 
january_data = housing_data[housing_data["Period End"] == "1/31/16"]
january_median_price = january_data["Median Sale Price"]
january_median_dom = january_data["Median Dom"]

# %%
#Bubble Chart = month on x-axis, median sale price on y-axis, size of bubble will be median dom, color will be city

# %%
plt.scatter(january_median_dom,january_median_price)

# %%
plt.show()

# %%
#Bubble chart 
chicago_data = housing_data[housing_data['Region'] == 'Chicago, IL']
dc_data = housing_data[housing_data['Region'] == 'Washington, DC']
denver_data = housing_data[housing_data['Region'] == 'Denver, CO']
dallas_data = housing_data[housing_data['Region'] == 'Dallas, TX']
san_diego_data = housing_data[housing_data['Region'] == 'San Diego, CA']
national_data = housing_data[housing_data['Region'] == 'National']

# %%
#chicago monthly data
chicago_january = chicago_data[chicago_data["Period End"] == "1/31/16"]
chicago_january_price = chicago_january["Median Sale Price"]
chicago_january_dom = chicago_january["Median Dom"]
#February
chicago_february = chicago_data[chicago_data["Period End"] == "2/29/16"]
chicago_february_price = chicago_february["Median Sale Price"]
chicago_february_dom = chicago_february["Median Dom"]
#March
chicago_march = chicago_data[chicago_data["Period End"] == "3/31/16"]
chicago_march_price = chicago_march["Median Sale Price"]
chicago_march_dom = chicago_march["Median Dom"]

# %%
#DC Monthly Data
dc_january = dc_data[dc_data["Period End"] == "1/31/16"]
dc_january_price = dc_january["Median Sale Price"]
dc_january_dom = dc_january["Median Dom"]
#February
dc_february = dc_data[dc_data["Period End"] == "2/29/16"]
dc_february_price = dc_february["Median Sale Price"]
dc_february_dom = dc_february["Median Dom"]
#March
dc_march = dc_data[dc_data["Period End"] == "3/31/16"]
dc_march_price = dc_march["Median Sale Price"]
dc_march_dom = dc_march["Median Dom"]

# %%
#Denver Monthly Data
denver_january = denver_data[denver_data["Period End"] == "1/31/16"]
denver_january_price = denver_january["Median Sale Price"]
denver_january_dom = denver_january["Median Dom"]
#February
denver_february = denver_data[denver_data["Period End"] == "2/29/16"]
denver_february_price = denver_february["Median Sale Price"]
denver_february_dom = denver_february["Median Dom"]
#March
denver_march = denver_data[denver_data["Period End"] == "3/31/16"]
denver_march_price = denver_march["Median Sale Price"]
denver_march_dom = denver_march["Median Dom"]

# %%
#Dallas Monthly Data
dallas_january = dallas_data[dallas_data["Period End"] == "1/31/16"]
dallas_january_price = dallas_january["Median Sale Price"]
dallas_january_dom = dallas_january["Median Dom"]
#February
dallas_february = dallas_data[dallas_data["Period End"] == "2/29/16"]
dallas_february_price = dallas_february["Median Sale Price"]
dallas_february_dom = dallas_february["Median Dom"]
#March
dallas_march = dallas_data[dallas_data["Period End"] == "3/31/16"]
dallas_march_price = dallas_march["Median Sale Price"]
dallas_march_dom = dallas_march["Median Dom"]

# %%
plt.scatter(chicago_data["Median Dom"], 
            chicago_data["Median Sale Price"], c="red",
            s=chicago_data["Homes Sold"]*.25,
                 edgecolor ="black",
                linewidths=1, marker="o", alpha=0.8, label="Chicago")

plt.scatter(dc_data["Median Dom"], 
            dc_data["Median Sale Price"], c="blue", 
            s=dc_data["Homes Sold"]*.25,
                 edgecolor ="black",
                linewidths=1, marker="o", alpha=0.8, label="DC")

plt.scatter(denver_data["Median Dom"], 
            denver_data["Median Sale Price"],c="green",
            s=denver_data["Homes Sold"]*.25,
                 edgecolor ="black",
                linewidths=1, marker="o", alpha=0.8, label="Denver")

plt.scatter(dallas_data["Median Dom"], 
            dallas_data["Median Sale Price"], c="purple", 
            s=dallas_data["Homes Sold"]*.25,
                 edgecolor ="black",
                linewidths=1, marker="o", alpha=0.8, label="Dallas")

plt.scatter(san_diego_data["Median Dom"], 
            san_diego_data["Median Sale Price"],c="yellow",
            s=san_diego_data["Homes Sold"]*.25,
                 edgecolor ="black",
                linewidths=1, marker="o", alpha=0.8, label="San Diego")


plt.xlim(0,95)
lgnd = plt.legend(fontsize="small", mode="Expanded", 
                  numpoints=1, scatterpoints=1, 
                  loc="best", title="City Names", 
                  labelspacing=0.5)
lgnd.legendHandles[0]._sizes = [30]
lgnd.legendHandles[1]._sizes = [30]
lgnd.legendHandles[2]._sizes = [30]
lgnd.legendHandles[3]._sizes = [30]
lgnd.legendHandles[4]._sizes = [30]
plt.legend()
plt.grid(True)

plt.show()
