# %%
import pandas as pd

csv_path = "Housing_Data.csv"
housing_df = pd.read_csv(csv_path)
housing_df.head()
# Out:
#   Worksheet Filter  Measure Display  Number of Records  Avg Sale To List  \
# 0            Value              NaN                  1          0.968704
# 1            Value              NaN                  1          0.970827
# 2            Value              NaN                  1          0.980057
# 3            Value              NaN                  1          0.986222
# 4            Value              NaN                  1          0.983040
#
#   Avg Sale To List Mom Avg Sale To List Yoy     City  Homes Sold  \
# 0                0.00%               -0.10%  Chicago        2098
# 1                0.20%                0.40%  Chicago        1876
# 2                0.90%                0.80%  Chicago        2393
# 3                0.60%                1.00%  Chicago        2908
# 4               -0.30%                0.10%  Chicago        3204
#
#   Homes Sold Mom Homes Sold Yoy    ...     Price Drops Yoy    Property Type  \
# ...
